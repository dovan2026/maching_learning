# %% [markdown]
# # 1.환경 준비

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
# 데이터 불러오기
path = 'data/mobile_cust_churn.csv'
df = pd.read_csv(path)
df['CHURN'] = df['CHURN'].map({'STAY':0, 'LEAVE': 1})

# %% [markdown]
# # 2.데이터 이해

# %%
# 데이터 살펴보기
df.head()
# Out:
#    id  COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0   1        0   31953        0         6  313378            161
# 1   2        1   36147        0        13  800586            244
# 2   3        1   27273      230         0  305049            201
# 3   4        0  120070       38        33  788235            780
# 4   5        1   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  CHURN
# 0               little                         no      0
# 1               little                considering      0
# 2          very_little                    perhaps      0
# 3            very_high                considering      1
# 4               little              never_thought      0

# %% [markdown]
# **데이터 설명**
#
# - COLLEGE: 대학 졸업여부
# - INCOME: 연수입
# - OVERAGE: 월평균 초과사용 시간(분)
# - LEFTOVER: 월평균 잔여시간비율(%)
# - HOUSE: 집값
# - HANDSET_PRICE: 스마트폰 가격
# - OVER_15MINS_CALLS_PER_MONTH: 월평균 장기통화(15분이상) 횟수
# - AVERAGE_CALL_DURATION: 평균 통화 시간
# - REPORTED_SATISFACTION: 만족도 설문조사 결과
# - REPORTED_USAGE_LEVEL: 사용도 자가진단 결과
# - CONSIDERING_CHANGE_OF_PLAN: 향후 변경계획 설문조사 결과
# - CHURN: 이탈(번호이동) 여부

# %%
# 기술통계 확인
df.describe()
# Out:
#                  id       COLLEGE         INCOME       OVERAGE      LEFTOVER  \
# count  20000.000000  20000.000000   20000.000000  20000.000000  20000.000000
# mean   10000.500000      0.502400   80281.447750     85.979550     23.898650
# std     5773.647028      0.500007   41680.586319     85.992324     26.816645
# min        1.000000      0.000000   20007.000000     -2.000000      0.000000
# 25%     5000.750000      0.000000   42217.000000      0.000000      0.000000
# 50%    10000.500000      1.000000   75366.500000     59.000000     14.000000
# 75%    15000.250000      1.000000  115881.750000    179.000000     41.000000
# max    20000.000000      1.000000  159983.000000    335.000000     89.000000
#
#                HOUSE  HANDSET_PRICE  OVER_15MINS_CALLS_PER_MONTH  \
# count   20000.000000   20000.000000                 20000.000000
# mean   493155.264250     389.615100                     8.000700
# std    252407.884692     213.820682                     8.925418
# min    150002.000000     130.000000                     0.000000
# 25%    263714.250000     219.000000                     1.000000
# 50%    452259.500000     326.000000                     4.000000
# 75%    702378.000000     533.250000                    15.000000
# max    999996.000000     899.000000                    29.000000
#
#        AVERAGE_CALL_DURATION         CHURN
# count           20000.000000  20000.000000
# mean                6.002250      0.492600
# std                 4.402558      0.499958
# min                 1.000000      0.000000
# 25%                 2.000000      0.000000
# 50%                 5.000000      0.000000
# 75%                10.000000      1.000000
# max                15.000000      1.000000

# %% [markdown]
# # 3.데이터 전처리

# %% [markdown]
# **1) 변수 제거**

# %%
# 제거 대상: id
drop_cols = ['id']

# 변수 제거
df.drop(drop_cols, axis=1, inplace=True)

# 확인
df.head()
# Out:
#    COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0        0   31953        0         6  313378            161
# 1        1   36147        0        13  800586            244
# 2        1   27273      230         0  305049            201
# 3        0  120070       38        33  788235            780
# 4        1   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  CHURN
# 0               little                         no      0
# 1               little                considering      0
# 2          very_little                    perhaps      0
# 3            very_high                considering      1
# 4               little              never_thought      0

# %% [markdown]
# **2) x, y 분리**

# %%
# Target 설정
target = 'CHURN'

# 데이터 분리
X = df.drop(target, axis=1)
y = df[target]

# %% [markdown]
# **3) 가변수화**

# %%
# 가변수화 대상: REPORTED_SATISFACTION, REPORTED_USAGE_LEVEL, CONSIDERING_CHANGE_OF_PLAN
df_dummies = ['REPORTED_SATISFACTION', 'REPORTED_USAGE_LEVEL', 'CONSIDERING_CHANGE_OF_PLAN']

# 가변수화
X = pd.get_dummies(X, columns=df_dummies, drop_first=True)

# 확인
X.head()
# Out:
#    COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0        0   31953        0         6  313378            161
# 1        1   36147        0        13  800586            244
# 2        1   27273      230         0  305049            201
# 3        0  120070       38        33  788235            780
# 4        1   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION  \
# 0                            0                      4
# 1                            0                      6
# 2                           16                     15
# 3                            3                      2
# 4                           21                      1
#
#    REPORTED_SATISFACTION_sat  REPORTED_SATISFACTION_unsat  \
# 0                      False                         True
# 1                      False                         True
# 2                      False                         True
# 3                      False                         True
# 4                      False                        False
#
#    REPORTED_SATISFACTION_very_sat  REPORTED_SATISFACTION_very_unsat  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                              True
#
#    REPORTED_USAGE_LEVEL_high  REPORTED_USAGE_LEVEL_little  \
# 0                      False                         True
# 1                      False                         True
# 2                      False                        False
# 3                      False                        False
# 4                      False                         True
#
#    REPORTED_USAGE_LEVEL_very_high  REPORTED_USAGE_LEVEL_very_little  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                              True
# 3                            True                             False
# 4                           False                             False
#
#    CONSIDERING_CHANGE_OF_PLAN_considering  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
#
#    CONSIDERING_CHANGE_OF_PLAN_never_thought  CONSIDERING_CHANGE_OF_PLAN_no  \
# 0                                     False                           True
# 1                                     False                          False
# 2                                     False                          False
# 3                                     False                          False
# 4                                      True                          False
#
#    CONSIDERING_CHANGE_OF_PLAN_perhaps
# 0                               False
# 1                               False
# 2                                True
# 3                               False
# 4                               False

# %% [markdown]
# **4) 학습용, 평가용 데이터 분리**

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 7:3으로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.7,
                                                    random_state=1
                                                    )

# %% [markdown]
# **5) 정규화**

# %%
# 모듈 불러오기
from sklearn.preprocessing import MinMaxScaler

# 정규화
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # 4.성능 예측
#
# - 여러 알고리즘으로 모델을 만들고 K-Fold CV로 성능을 예측한다.
# - 하이퍼파라미터를 설정하지 않고 진행한다.
# - 각 모델의 성능 정보를 수집해 마지막에 비교한다.

# %%
# xgboost 설치
# pip install xgboost

# %%
# lightgbm 설치
# pip install lightgbm

# %% [markdown]
# - 이후 사용할 함수 모두 불러오기

# %%
# 라이브러리 불러오기
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import *
from sklearn.model_selection import cross_val_score

# %% [markdown]
# **1) KNN**
#
# - KNN 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_knn = KNeighborsClassifier()

# %%
# 성능예측
cv_score = cross_val_score(model_knn, X_train, y_train, cv=5, scoring ='accuracy')

# %%
# 결과확인
print(cv_score)
print('평균 :', cv_score.mean())
print('표준편차 :', cv_score.std())
# Out:
# [0.58571429 0.60035714 0.57785714 0.60321429 0.59785714]
# 평균 : 0.5930000000000001
# 표준편차 : 0.009637829377097347

# %%
# 결과수집
result = {}
result['KNN'] = cv_score.mean()

# %% [markdown]
# **2) Decision Tree**
#
# - Decision Tree 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_dt = DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
# 성능예측
cv_score = cross_val_score(model_dt, X_train, y_train, cv=5, scoring='accuracy')

# %%
# 결과확인
print(cv_score)
print('평균 :', cv_score.mean())
print('표준편차 :', cv_score.std())
# Out:
# [0.69642857 0.69821429 0.69071429 0.69857143 0.69714286]
# 평균 : 0.6962142857142857
# 표준편차 : 0.0028535691936340257

# %%
# 결과수집
result['DT'] = cv_score.mean()

# %% [markdown]
# **3) Logistic Regression**
#
# - Logistic Regression 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_lr = LogisticRegression()

# %%
# 성능예측
cv_score = cross_val_score(model_lr, X_train, y_train, cv=5, scoring='accuracy')

# %%
# 결과확인
print(cv_score)
print('평균 :', cv_score.mean())
print('표준편차 :', cv_score.std())
# Out:
# [0.63892857 0.64214286 0.63714286 0.65       0.6425    ]
# 평균 : 0.6421428571428571
# 표준편차 : 0.004408942674860292

# %%
# 결과수집
result['LR'] = cv_score.mean()

# %% [markdown]
# **4) SVM**
#
# - SVM 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_svc = SVC(kernel='linear', C=1, random_state=1)

# %%
# 성능예측
cv_score = cross_val_score(model_svc, X_train, y_train, cv=5, scoring='accuracy')

# %%
# 결과확인
print(cv_score)
print('평균 :', cv_score.mean())
print('표준편차 :', cv_score.std())
# Out:
# [0.62964286 0.6425     0.63142857 0.6475     0.64607143]
# 평균 : 0.6394285714285715
# 표준편차 : 0.00746283307806224

# %%
# 결과수집
result['SVC'] = cv_score.mean()

# %% [markdown]
# **5) Random Forest**
#
# - Random Forest 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_rf = RandomForestClassifier()

# %%
# 성능예측
cv_score = cross_val_score(model_rf, X_train, y_train, cv=5, scoring='accuracy')

# %%
# 결과확인
print(cv_score)
print(cv_score.mean())
print(cv_score.std())
# Out:
# [0.67928571 0.69928571 0.68142857 0.68857143 0.695     ]
# 0.6887142857142857
# 0.007658528659245839

# %%
# 결과수집
result['RF'] = cv_score.mean()

# %% [markdown]
# **6) XGBoost**
#
# - XGBoost 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_xgb = XGBClassifier()

# %%
# 성능예측
cv_score = cross_val_score(model_xgb, X_train, y_train, cv=5, scoring='accuracy')

# %%
# 결과확인
print(cv_score)
print(cv_score.mean())
print(cv_score.std())
# Out:
# [0.67857143 0.69607143 0.67892857 0.69285714 0.68678571]
# 0.6866428571428573
# 0.0071020261552745545

# %%
# 결과수집
result['XGB'] = cv_score.mean()

# %% [markdown]
# **7) LightGBM**
#
# - LightGBM 알고리즘으로 모델링하고 K-Fold CV로 성능 검증

# %%
# 선언하기
model_lgbm = LGBMClassifier(min_child_samples=5,
                            max_depth=15,
                            min_split_gain=0.0,
                            colsample_bytree=1.0,
                            verbose=-1
                            )

# %%
# 성능예측
cv_score = cross_val_score(model_lgbm, X_train, y_train, cv=5, scoring='accuracy')

# %%
# 결과확인
print(cv_score)
print(cv_score.mean())
print(cv_score.std())
# Out:
# [0.68535714 0.71142857 0.69035714 0.6925     0.69821429]
# 0.6955714285714285
# 0.008937424182638296

# %%
# 결과수집
result['LGBM'] = cv_score.mean()

# %% [markdown]
# # 5.결과 확인
#
# - 예측된 각 모델의 성능 비교

# %%
# 성능 비교
df_result = pd.DataFrame.from_dict(result, orient='index', columns=['score'])
df_result.sort_values(by='score', ascending=True, inplace=True)

# %%
# 성능 시각화 비교
plt.figure(figsize=(8,8))
plt.barh(y=df_result.index, width=df_result['score'])
plt.xlabel('Score')
plt.ylabel('Model')
plt.show()

# %% [markdown]
# # 6.성능 튜닝
#
# - 위에서 성능이 가장 좋을 것으로 예측된 모델 튜닝

# %%
from sklearn.model_selection import GridSearchCV
# 기본 모델 선언
modelno1 = model_dt

# 파라미터 지정
param = {'max_depth': range(1,51)}


# 모델 선언
model = GridSearchCV(modelno1,
                      param,
                      cv=5,
                      scoring='accuracy')

# %%
# 학습하기(많은 시간이 소요될 수 있음)
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=DecisionTreeClassifier(max_depth=5, random_state=1),
#              param_grid={'max_depth': range(1, 51)}, scoring='accuracy')

# %%
# mean_test_score 확인
print(model.cv_results_['mean_test_score'])
print('='*70)
print('최적의 파라미터: ', model.best_params_)
print('='*70)
print('최고의 성능: ', model.best_score_)
# Out:
# [0.61735714 0.65607143 0.68907143 0.69964286 0.69621429 0.69757143
#  0.69728571 0.69414286 0.68785714 0.67864286 0.67371429 0.668
#  0.65714286 0.65564286 0.65078571 0.64378571 0.63907143 0.63507143
#  0.63271429 0.62421429 0.62285714 0.62421429 0.61707143 0.619
#  0.62078571 0.6205     0.61614286 0.617      0.61785714 0.61792857
#  0.61435714 0.61571429 0.61628571 0.61585714 0.61521429 0.61492857
#  0.61492857 0.61492857 0.61492857 0.61492857 0.61492857 0.61492857
#  0.61492857 0.61492857 0.61492857 0.61492857 0.61492857 0.61492857
#  0.61492857 0.61492857]
# ======================================================================
# 최적의 파라미터:  {'max_depth': 4}
# ======================================================================
# 최고의 성능:  0.6996428571428571

# %%
# 변수 중요도 데이터 만들기
importances = model.best_estimator_.feature_importances_
feature_names = X.columns  # X가 DataFrame일 때

fi = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
})

# 중요도 순으로 정렬
fi = fi.sort_values(by='importance', ascending=True)

# 시각화
plt.figure(figsize=(8, 8))
plt.barh(fi['feature'], fi['importance'])
plt.show()

# %% [markdown]
# # 7.성능 평가
#
# - 최적 파라미터로 학습된 모델에 대해 최종 성능 평가 진행

# %%
# 예측하기
y_pred = model.predict(X_test)

# %%
# 평가하기
print('CM :', confusion_matrix(y_test, y_pred))
print('='*70)
print('Class_report :', classification_report(y_test, y_pred))
# Out:
# CM : [[1930 1135]
#  [ 646 2289]]
# ======================================================================
# Class_report :               precision    recall  f1-score   support
#
#            0       0.75      0.63      0.68      3065
#            1       0.67      0.78      0.72      2935
#
#     accuracy                           0.70      6000
#    macro avg       0.71      0.70      0.70      6000
# weighted avg       0.71      0.70      0.70      6000
