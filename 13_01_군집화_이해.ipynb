# %% [markdown]
# # 1.라이브러리 및 데이터 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('example_cluster.csv')
df.head()

# %% [markdown]
# - 시각화 확인

# %%
sns.scatterplot(x='var_1', y='var_2', data=df)
plt.show()

# %% [markdown]
# # 2.군집화 이해

# %% [markdown]
# **1) 라이브러리 불러오기**

# %% [markdown]
# **2) 선언하기**

# %% [markdown]
# **3) 학습하기**

# %% [markdown]
# **4) 예측하기**

# %% [markdown]
# - 군집 개수 늘려보기

# %% [markdown]
# - 최적의 군집 개수 찾기
